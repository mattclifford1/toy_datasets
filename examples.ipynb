# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import data_loaders

# %%
data_loaders.get_available_dataset_list()
# Out:
# ['XOR',
#  'Moons',
#  'Blobs',
#  'Circles',
#  'Sklearn Normal',
#  'Abalone Gender',
#  'Banknote Authentication',
#  'Breast Cancer Wisconsin',
#  'Cervical Cancer',
#  'Chronic Kidney Disease',
#  'Costcla Credit Scoring Kaggle 2011',
#  'Costcla Credit Scoring PAKDD 2009',
#  'Costcla Direct Marketing',
#  'Diabetes Pima Indian',
#  'Habermans Breast Cancer',
#  'Heart Disease',
#  'Hepatitis',
#  'Ionosphere',
#  'MNIST',
#  'Sonar Rocks vs Mines',
#  'Wheat Seeds']

# %%
data_name = 'Sklearn Normal'
dataset = data_loaders.get_dataset(data_name)

# %%
print(dataset)
# Out:
# Data Loader for Sklearn Synthetic Classification (Normal) dataset

# %%
dataset.plot_dataset()
# Out:
# Dataset: Sklearn Synthetic Classification (Normal)
#     - Number of features: 20
#     - Total instances: 200
#       - Class 0: 102 instances
#       - Class 1: 98 instances
