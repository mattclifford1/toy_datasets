# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import data_loaders

# %%
data_loaders.get_available_dataset_list()
# Out:
# ['XOR',
#  'Moons',
#  'Abalone Gender',
#  'Banknote Authentication',
#  'Breast Cancer Wisconsin',
#  'Cervical Cancer',
#  'Chronic Kidney Disease',
#  'Costcla Credit Scoring Kaggle 2011',
#  'Costcla Credit Scoring PAKDD 2009',
#  'Costcla Direct Marketing',
#  'Diabetes Pima Indian',
#  'Habermans Breast Cancer',
#  'Heart Disease',
#  'Hepatitis',
#  'Ionosphere',
#  'MNIST',
#  'Sonar Rocks vs Mines',
#  'Wheat Seeds']

# %%
data_name = 'Circles'
dataset = data_loaders.get_dataset(data_name)

# %%
print(dataset)
# Out:
# Data Loader for Circles Synthetic dataset

# %%
dataset.plot_dataset()
# Out:
# Dataset: Circles Synthetic
#     - Number of features: 2
#     - Total instances: 200
#       - Class 0: 100 instances
#       - Class 1: 100 instances
